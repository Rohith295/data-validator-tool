# %% [markdown]
# # Sample Files Walkthrough
#
# Validate a few files from `sample_data/` using `validate_file()`.
#
# This is a practical notebook for checking how the library behaves against the same sample inputs used by the CLI.

# %%
from pathlib import Path

from data_validator import ReportView, validate_file

# %%
ROOT = Path.cwd()
if not (ROOT / "sample_data").exists():
    ROOT = ROOT.parent

ROOT
# Out:
# PosixPath('/Users/rohithrangaraju/personal_projects/data-validator-tool')

# %%
good_csv = ROOT / "sample_data" / "1.csv"
bad_csv = ROOT / "sample_data" / "4.csv"
default_schema = ROOT / "sample_data" / "my_schema.json"
messy_csv = ROOT / "sample_data" / "messy.csv"
messy_schema = ROOT / "sample_data" / "messy_schema.json"

good_csv, bad_csv, default_schema
# Out:
# (PosixPath('/Users/rohithrangaraju/personal_projects/data-validator-tool/sample_data/1.csv'),
#  PosixPath('/Users/rohithrangaraju/personal_projects/data-validator-tool/sample_data/4.csv'),
#  PosixPath('/Users/rohithrangaraju/personal_projects/data-validator-tool/sample_data/my_schema.json'))

# %%
good_report = validate_file(good_csv, default_schema)
bad_report = validate_file(bad_csv, default_schema)
messy_report = validate_file(messy_csv, messy_schema)

# %%
[("1.csv", good_report.overall_passed), ("4.csv", bad_report.overall_passed), ("messy.csv", messy_report.overall_passed)]
# Out:
# [('1.csv', True), ('4.csv', False), ('messy.csv', False)]

# %%
bad_view = ReportView(bad_report)
bad_view.summary()
# Out:
# shape: (3, 4)
# ┌─────────────────┬────────┬────────┬────────────┐
# │ check           ┆ passed ┆ errors ┆ elapsed_ms │
# │ ---             ┆ ---    ┆ ---    ┆ ---        │
# │ str             ┆ bool   ┆ i64    ┆ f64        │
# ╞═════════════════╪════════╪════════╪════════════╡
# │ columns_check   ┆ true   ┆ 0      ┆ 0.004      │
# │ non_empty_check ┆ true   ┆ 0      ┆ 0.591      │
# │ types_check     ┆ false  ┆ 2      ┆ 2.177      │
# └─────────────────┴────────┴────────┴────────────┘

# %%
bad_view.errors_df()
# Out:
# shape: (2, 5)
# ┌─────────────┬─────┬────────┬─────────────────────────┬────────────┐
# │ check       ┆ row ┆ column ┆ message                 ┆ value      │
# │ ---         ┆ --- ┆ ---    ┆ ---                     ┆ ---        │
# │ str         ┆ i64 ┆ str    ┆ str                     ┆ str        │
# ╞═════════════╪═════╪════════╪═════════════════════════╪════════════╡
# │ types_check ┆ 1   ┆ age    ┆ Expected type 'integer' ┆ Fifty      │
# │ types_check ┆ 2   ┆ age    ┆ Expected type 'integer' ┆ Forty four │
# └─────────────┴─────┴────────┴─────────────────────────┴────────────┘

# %%
bad_view
# Out:
# ReportView(FAIL, 3 checks)

# %%
reports_dir = ROOT / "reports"
reports_dir.mkdir(exist_ok=True)

output_path = reports_dir / "sample_files_notebook_report.html"
bad_view.save_html(str(output_path))
output_path
# Out:
# PosixPath('/Users/rohithrangaraju/personal_projects/data-validator-tool/reports/sample_files_notebook_report.html')
